# %%
import pandas as pd
import numpy as np
import os

# %%
path = '/Users/pgtips/Desktop/Instacart Basket Analysis/02.Data/Prepared Data'

# %%
df_merged = pd.read_pickle(os.path.join(path, 'orders_products_merged.pkl'))

# %%
df_merged=df_merged.drop(['Unnamed: 0'],axis=1)

# %%
df = df_merged[:1000000]

# %%
df
# Out:
#         order_id  user_id  number  days  hours  days_since_prior_order  \
# 0        2539329        1       1     2      8                     0.0
# 1        2398795        1       2     3      7                    15.0
# 2         473747        1       3     3     12                    21.0
# 3        2254736        1       4     4      7                    29.0
# 4         431534        1       5     4     15                    28.0
# ...          ...      ...     ...   ...    ...                     ...
# 999995   2836489   164627      14     0     15                     6.0
# 999996   1843600   164632       5     1     19                     9.0
# 999997    733106   164632       9     2     22                    10.0
# 999998   1650124   164632      17     6     17                    13.0
# 999999   3378258   164632      22     6     10                    15.0
#
#         product_id  add_to_cart_order  reordered _merge     product_name  \
# ...

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range'
  else: return 'Not enough data'

# %%
df.shape
# Out:
# (1000000, 15)

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# /var/folders/b1/sjmlj2t54lng5qhx5tkfs5km0000gn/T/ipykernel_2923/2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.head()
# Out:
#    order_id  user_id  number  days  hours  days_since_prior_order  product_id  \
# 0   2539329        1       1     2      8                     0.0         196
# 1   2398795        1       2     3      7                    15.0         196
# 2    473747        1       3     3     12                    21.0         196
# 3   2254736        1       4     4      7                    29.0         196
# 4    431534        1       5     4     15                    28.0         196
#
#    add_to_cart_order  reordered _merge product_name  aisle_id  department_id  \
# 0                  1          0   both         Soda        77              7
# 1                  1          1   both         Soda        77              7
# 2                  1          1   both         Soda        77              7
# 3                  1          1   both         Soda        77              7
# 4                  1          1   both         Soda        77              7
#
# ...

# %%
df['price_range'].value_counts (dropna=False)
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range, dtype: int64

# %%
df['prices'].max()
# Out:
# 14.8

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product' 
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'
# Out:
# /Users/pgtips/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1684: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/pgtips/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
df['price_range_loc'].value_counts()
# Out:
# Mid-range product    756450
# Low-range product    243550
# Name: price_range_loc, dtype: int64

# %%
df_merged.loc[df_merged['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df_merged.loc[(df_merged['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df_merged.loc[df_merged['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df_merged['price_range_loc'].value_counts()
# Out:
# Low-range product     10126366
# Mid-range product       756450
# High-range product      417678
# Name: price_range_loc, dtype: int64

# %%
df_merged['days'].value_counts()
# Out:
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: days, dtype: int64

# %%
result = []

for value in df_merged ["days"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_merged['busiest_day'] = result

# %%
df_merged['busiest_day'].value_counts(dropna = False)
# Out:
# Regularly busy    22417684
# Busiest day        6204404
# Least busy         3783953
# Name: busiest_day, dtype: int64

# %%
result = []
for value in df_merged ['days']:
    if value == 0:
        result.append ("busiest days")
    elif value == 1:
        result.append ('busiest days')
    elif value == 3:
        result.append ('least busy')
    elif value == 4:
        result.append ('least busy')
    else:
        result.append ('regular day')

# %%
df_merged['busiest_day'] = result

# %%
df_merged ['busiest_day'].value_counts(dropna=False)
# Out:
# regular day     12916527
# busiest days    11864860
# least busy       7624654
# Name: busiest_day, dtype: int64

# %%
df_merged.loc[df_merged['days'] == 0, 'busiest_days_loc'] = 'busiest days'

# %%
df_merged.loc[df_merged['days'] == 1, 'busiest_days_loc'] = 'busiest days'

# %%
df_merged.loc[df_merged ['days'] == 4, 'busiest_days_loc'] = 'least busiest day'

# %%
df_merged.loc[df_merged ['days'] == 3, 'busiest_days_loc'] = 'least busiest day'

# %%
df_merged.loc[df_merged ['days'] == 2 , 'busiest_days_loc'] = 'regular days'

# %%
df_merged.loc[df_merged ['days'] == 5 , 'busiest_days_loc'] = 'regular days'

# %%
df_merged.loc[df_merged ['days'] == 6 , 'busiest_days_loc'] = 'regular days'

# %%
df_merged ['busiest_days_loc'].value_counts(dropna= False)
# Out:
# regular days         12916527
# busiest days         11864860
# least busiest day     7624654
# Name: busiest_days_loc, dtype: int64

# %%
df_merged
# Out:
#           order_id  user_id  number  days  hours  days_since_prior_order  \
# 0          2539329        1       1     2      8                     0.0
# 1          2398795        1       2     3      7                    15.0
# 2           473747        1       3     3     12                    21.0
# 3          2254736        1       4     4      7                    29.0
# 4           431534        1       5     4     15                    28.0
# ...            ...      ...     ...   ...    ...                     ...
# 32406036   1320836   202557      17     2     15                     1.0
# 32406037     31526   202557      18     5     11                     3.0
# 32406038    758936   203436       1     2      7                     0.0
# 32406039   2745165   203436       2     3      5                    15.0
# 32406040   3093936   205420       1     4     14                     0.0
#
#           product_id  add_to_cart_order  reordered _merge  \
# ...

# %%
df_merged ['days'].value_counts()
# Out:
# 0    6204404
# 1    5660456
# 6    4496635
# 2    4213986
# 5    4205906
# 3    3840701
# 4    3783953
# Name: days, dtype: int64

# %%
df_merged['hours'].value_counts()
# Out:
# 10    2761862
# 11    2736242
# 14    2689251
# 15    2662246
# 13    2661057
# 12    2618613
# 16    2535313
# 9     2454273
# 17    2087721
# 8     1718182
# 18    1636566
# 19    1258352
# 20     976182
# 7      891082
# 21     795658
# 22     634247
# 23     402335
# 6      290500
# 0      218786
# 1      115706
# 5       87964
# 2       69377
# 4       53245
# 3       51281
# Name: hours, dtype: int64

# %%
new_results = []

for value in df_merged["hours"]:
    if value >= 9:
        new_results.append ('Most orders')
    elif value <=6:
        new_results.append ('Fewest orders')
    else:
        new_results.append ('Average orders')

# %%
new_results
# Out:
# ['Average orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Average orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
#  'Most orders',
# ...

# %%
df_merged['busiest_hours'] = new_results

# %%
df_merged['busiest_hours'].value_counts(dropna=False)
# Out:
# Most orders       28909918
# Average orders     2609264
# Fewest orders       886859
# Name: busiest_hours, dtype: int64

# %%
df_merged.to_pickle(os.path.join(path, 'prods_ords_V47.pkl'))
