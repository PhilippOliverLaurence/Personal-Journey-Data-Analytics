# %%
# Importing the merged data set
import pandas as pd
import numpy as np
import os

# %%
df_ords_prods_merge = pd.read_pickle(r'/Users/pgtips/Desktop/Instacart Basket Analysis/02.Data/Prepared Data/ords_prods.pkl')

# %%
df_ords_prods_merge
# Out:
#           order_id  user_id  number  days  hours  days_since_order  \
# 0          2539329        1       1     2      8               NaN
# 1          2539329        1       1     2      8               NaN
# 2          2539329        1       1     2      8               NaN
# 3          2539329        1       1     2      8               NaN
# 4          2539329        1       1     2      8               NaN
# ...            ...      ...     ...   ...    ...               ...
# 32434484   2977660   206209      13     1     12               7.0
# 32434485   2977660   206209      13     1     12               7.0
# 32434486   2977660   206209      13     1     12               7.0
# 32434487   2977660   206209      13     1     12               7.0
# 32434488   2977660   206209      13     1     12               7.0
#
#           product_id  add_to_cart_order  reordered _merge
# 0                196                  1          0   both
# ...

# %%
df_prods = pd.read_csv(r'/Users/pgtips/Desktop/Instacart Basket Analysis/02.Data/Prepared Data/products.csv')

# %%
df_prods
# Out:
#        Unnamed: 0  product_id  \
# 0               0           1
# 1               1           2
# 2               2           3
# 3               3           4
# 4               4           5
# ...           ...         ...
# 49672       49688       49684
# 49673       49689       49685
# 49674       49690       49686
# 49675       49691       49687
# 49676       49692       49688
#
#                                             product_name  aisle_id  \
# 0                             Chocolate Sandwich Cookies        61
# 1                                       All-Seasons Salt       104
# 2                   Robust Golden Unsweetened Oolong Tea        94
# 3      Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4                              Green Chile Anytime Sauce         5
# ...                                                  ...       ...
# 49672          Vodka, Triple Distilled, Twist of Vanilla       124
# ...

# %%
df_merged_total = pd.merge(df_ords_prods_merge,df_prods, on = ['product_id'], how = 'inner', indicator='exists')

# %%
df_merged_total
# Out:
#           order_id  user_id  number  days  hours  days_since_prior_order  \
# 0          2539329        1       1     2      8                     0.0
# 1          2398795        1       2     3      7                    15.0
# 2           473747        1       3     3     12                    21.0
# 3          2254736        1       4     4      7                    29.0
# 4           431534        1       5     4     15                    28.0
# ...            ...      ...     ...   ...    ...                     ...
# 32406036   1320836   202557      17     2     15                     1.0
# 32406037     31526   202557      18     5     11                     3.0
# 32406038    758936   203436       1     2      7                     0.0
# 32406039   2745165   203436       2     3      5                    15.0
# 32406040   3093936   205420       1     4     14                     0.0
#
#           product_id  add_to_cart_order  reordered _merge  Unnamed: 0  \
# ...

# %%
df_merged_total['exists'].value_counts()
# Out:
# both          32406041
# left_only            0
# right_only           0
# Name: exists, dtype: int64

# %%
# We can see that we have successfully merged the product with the merged ords_prods from part 1

# %%
df_merged_total.to_pickle(r'/Users/pgtips/Desktop/Instacart Basket Analysis/02.Data/Prepared Data/orders_products_merged.pkl')
